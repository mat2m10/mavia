# %%
import pickle
import pandas as pd

# %%
with open('couple_dicts.pkl', 'rb') as file:
    couple_dicts = pickle.load(file)

# %%
couple_dicts["smith_jh@outlook.com"]
# Out:
#          dim1      dim2  Sex  cluster force sensitives force            name  \
# 43  15.291653 -0.817714    1        0  sith woman (13)  sith            Ilse
# 22  15.319916 -0.452877    1        0  sith woman (13)  sith            Ines
# 18  15.587365 -1.453601    1        1  jedi woman (14)  jedi          Lauraa
# 37  14.922102 -1.686982    1        1  jedi woman (14)  jedi           Karen
# 44  14.346979 -1.417053    1        0  sith woman (13)  sith          Claire
# 6   15.568912 -2.294645    1        1  jedi woman (14)  jedi         Eugenie
# 23  15.878200 -2.517871    1        1  jedi woman (14)  jedi           Xenia
# 40  15.342551 -2.578406    1        1  jedi woman (14)  jedi         Camilla
# 5   14.423122 -2.114303    1        1  jedi woman (14)  jedi  Anne Katharina
# 47  13.910199 -1.101399    1        0  sith woman (13)  sith           Nikou
# 4   14.119574 -1.753878    1        0  sith woman (13)  sith           Lotti
# ...
